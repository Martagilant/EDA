# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
from bootcampviztools import plot_categorical_relationship_fin, pinta_distribucion_categoricas, plot_grouped_histograms,\
    plot_grouped_boxplots, plot_combined_graphs, plot_categorical_numerical_relationship, bubble_plot,\
        grafico_dispersion_con_correlacion
from scipy.stats import chi2_contingency, mannwhitneyu

# %%
df = pd.read_csv("./data/amazon_final.csv")

# %%
df.head()
# Out:
#                                                title           author  \
# 0               First 100 Words: A Padded Board Book     Roger Priddy
# 1  The Life-Changing Magic of Tidying Up: The Jap...      Marie Kondō
# 2                      Laugh-Out-Loud Jokes for Kids      Rob Elliott
# 3  Secret Garden: An Inky Treasure Hunt and Color...  Johanna Basford
# 4                                StrengthsFinder 2.0           Gallup
#
#                                genre  rating   price  year pages  \
# 0              Vocabulary & Spelling     4.7   3..88  2011    24
# 1  Cleaning, Caretaking & Relocating     4.5   9..42  2017   224
# 2                           Humorous     4.6   4..64  2022   128
# 3                       Use of Color     4.7  10..18  2013    96
# 4                         Management     4.1  28..52  2007   175
#
#           reviews  amazon_year Language            Categories  Total Pages  \
# 0  38,701 ratings         2015       en   Juvenile Nonfiction          NaN
# 1  59,251 ratings         2015       en          House & Home          NaN
# 2  12,125 ratings         2015       en   Juvenile Nonfiction          NaN
# 3  15,936 ratings         2015       en                   Art          NaN
# 4   8,423 ratings         2015       es  Business & Economics          NaN
#
#         Genres                  publisher
# 0  Non Fiction            Priddy Books US
# 1  Non Fiction            Ten Speed Press
# 2  Non Fiction              HarperCollins
# 3  Non Fiction  National Geographic Books
# 4  Non Fiction               Gallup Press

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        656 non-null    object
#  1   author       656 non-null    object
#  2   genre        656 non-null    object
#  3   rating       656 non-null    float64
#  4   price        656 non-null    object
#  5   year         656 non-null    int64
#  6   pages        656 non-null    object
#  7   reviews      656 non-null    object
#  8   amazon_year  656 non-null    int64
#  9   Language     654 non-null    object
#  10  Categories   656 non-null    object
#  11  Total Pages  0 non-null      float64
#  12  Genres       656 non-null    object
#  13  publisher    656 non-null    object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 71.9+ KB

# %% [markdown]
# Ok, so from our dataset, we have two columns tha are the same: "pages" and "Total pages", we can drop "Total pages" sibce its empty.
# We are also dropping language, I don´t think it adds anything to this analysis so well drop it.

# %%
df.drop(axis = 1, columns = ["Total Pages", "Language"], inplace = True )

# %%
df.head(60)
# Out:
#                                                      Title  \
# book_id
# 0                     First 100 Words: A Padded Board Book
# 1        The Life-Changing Magic of Tidying Up: The Jap...
# 2                            Laugh-Out-Loud Jokes for Kids
# 3        Secret Garden: An Inky Treasure Hunt and Color...
# 4                                      StrengthsFinder 2.0
# 5                               Go Set a Watchman: A Novel
# 6        Enchanted Forest: An Inky Quest and Coloring b...
# 7                              All the Light We Cannot See
# 8                                    The Girl on the Train
# 9           Adult Coloring Book: Stress Relieving Patterns
# 10                    Diary of a Wimpy Kid #10: Old School
# 11                                   To Kill a Mockingbird
# 12       Adult Coloring Book: Stress Relieving Animal D...
# 13       Adult Coloring Books: A Coloring Book for Adul...
# 14                            Humans of New York : Stories
# 15                                             The Martian
# 16                               Oh, the Places You'll Go!
# 18        4..84  1725          18   31,173 ratings         2015
# 19        9..50  2013          40   24,358 ratings         2015
# 20       10..60  2019         404   91,163 ratings         2015
# 21        9..09  2004         416   41,717 ratings         2015
# 22       10..65  2021         320   22,371 ratings         2015
# 23       12..12  2015         640  118,522 ratings         2015
# 24        6..50  2015          64    5,290 ratings         2015
# 25        9..99  1913         320   34,768 ratings         2015
# 26        7..88  2016         224   93,996 ratings         2015
# 27       11..95  2015         103    2,295 ratings         2015
# 28        5..38  2015          64    5,375 ratings         2015
# 29       15..89  2014         240   15,131 ratings         2015
# 30        8..41  2004         180   17,859 ratings         2015
# 31        9..19  2015          80    8,737 ratings         2015
# 32        9..82  2002         256   13,786 ratings         2015
# 33       39..22  2004         997    1,580 ratings         2015
# 34        9..58  2014         192   38,364 ratings         2015
# 35        8..71  2019         160   42,847 ratings         2015
# 36        4..30  2012          36   40,253 ratings         2015
# 37       11..36  2001          48    6,213 ratings         2015
# 38       14..57  2014         352   18,595 ratings         2015
# 39        8..24  2008         305   35,855 ratings         2015
# 40        9..48  2014         528   76,515 ratings         2015
# 41       12..12  2015         336    3,619 ratings         2015
# 42       11..46  2015         512   24,979 ratings         2015
# 43        9..95  2012          40   20,113 ratings         2015
# 44        9..05  1953         249   55,135 ratings         2015
# 45       12..99  2012         104   26,974 ratings         2015
# 46        8..36  2016          28   14,178 ratings         2015
# 47       14..89  2015          64    4,752 ratings         2015
# 48       14..68  2015         430   32,971 ratings         2015
# 49        3..86  1982          16   18,895 ratings         2015
# 50       13..27  2015         224    3,888 ratings         2015
# 51        3..99  2007          32    3,053 ratings         2015
# 52        5..88  2013          16    5,107 ratings         2015
# 53       11..71  2015         338    9,007 ratings         2015
# 54        7..93  1734         120   21,793 ratings         2015
# 55       19..76  2008         614    2,107 ratings         2015
# 56       13..76  2012         352   13,606 ratings         2015
# 57       14..78  2015         320    6,379 ratings         2015
# 58        5..57  2000          14   14,520 ratings         2015
# 59        7..85  2014         208  166,954 ratings         2015
#
#                         Categories       Genres  \
# book_id
# 0              Juvenile Nonfiction  Non Fiction
# 1                     House & Home  Non Fiction
# 2              Juvenile Nonfiction  Non Fiction
# 3                              Art  Non Fiction
# 4             Business & Economics  Non Fiction
# 5                          Fiction      Fiction
# 6                              Art  Non Fiction
# 7                          Fiction      Fiction
# 8                       Alcoholics  Non Fiction
# 9                              Art  Non Fiction
# 10                     Non Fiction  Non Fiction
# 11                         Fiction      Fiction
# 12                             Art  Non Fiction
# 13                           Games  Non Fiction
# 14                     Photography  Non Fiction
# 15                      Astronauts  Non Fiction
# 16                Juvenile Fiction      Fiction
# 17               Knock-knock jokes  Non Fiction
# 18             Juvenile Nonfiction  Non Fiction
# 19                Juvenile Fiction      Fiction
# 20             Sports & Recreation  Non Fiction
# 21                        Religion  Non Fiction
# 22                     Non Fiction  Non Fiction
# 23                         Fiction      Fiction
# 24                             Art  Non Fiction
# 25                       Self-Help  Non Fiction
# 26          Family & Relationships  Non Fiction
# 27                Crafts & Hobbies  Non Fiction
# 28                             Art  Non Fiction
# 29                         Cooking  Non Fiction
# 30                         Fiction      Fiction
# 31                             Art  Non Fiction
# 32            Business & Economics  Non Fiction
# 33                      Study Aids  Non Fiction
# 34                         Cooking  Non Fiction
# 35                     Non Fiction  Non Fiction
# 36                Juvenile Fiction      Fiction
# 37                         Fiction      Fiction
# 38                           Humor  Non Fiction
# 39             Young Adult Fiction      Fiction
# 40       Biography & Autobiography  Non Fiction
# 41            Business & Economics  Non Fiction
# 42                Juvenile Fiction      Fiction
# 43                Juvenile Fiction      Fiction
# 44                         Fiction      Fiction
# 45             Juvenile Nonfiction  Non Fiction
# 46                Juvenile Fiction      Fiction
# 47         Comics & Graphic Novels  Non Fiction
# 48                         History  Non Fiction
# 49                Juvenile Fiction      Fiction
# 50                         Cooking  Non Fiction
# 51                             Art  Non Fiction
# 52                     Non Fiction  Non Fiction
# 53                Health & Fitness  Non Fiction
# 54       Biography & Autobiography  Non Fiction
# 55                Health & Fitness  Non Fiction
# 56             Juvenile Nonfiction  Non Fiction
# 57                       Self-Help  Non Fiction
# 58                           Games  Non Fiction
# 59                         Fiction      Fiction
#
#                                     Publisher
# book_id
# 0                             Priddy Books US
# 1                             Ten Speed Press
# 2                               HarperCollins
# 3                   National Geographic Books
# 4                                Gallup Press
# 5                                      Harper
# 6                    Laurence King Publishing
# 7                          Simon and Schuster
# 8                                Random House
# 9                             Blue Star Press
# 10                               Amulet Books
# 11                                      Arrow
# 12                            Blue Star Press
# 13                       Mother Dearest Books
# 14                         St. Martin's Press
# 15                  National Geographic Books
# 16       Random House Books for Young Readers
# 17                                Baker Books
# 18                         Simon and Schuster
# 19                                    Penguin
# 20                                    Penguin
# 21                              Thomas Nelson
# 22                               Random House
# 23                          Sourcebooks, Inc.
# 24                 Courier Dover Publications
# 25                             Namaskar Books
# 26                           Moody Publishers
# 27                        Grupo Planeta Spain
# 28                 Courier Dover Publications
# 29                                     Rodale
# 30                                   Scribner
# 31                  National Geographic Books
# 32                          John Wiley & Sons
# 33                              College Board
# 34                             Hay House, Inc
# 35                        Hazelden Publishing
# 36                           Beach Lane Books
# 37                                    Penguin
# 38                                Hachette UK
# 39                      Bloomsbury Publishing
# 40                               Random House
# 41                         Simon and Schuster
# 42                                Noura Books
# 43                                     Puffin
# 44                                  Minotauro
# 45                              American Girl
# 46                           Candlewick Press
# 47                                Hachette UK
# 48                                      Crown
# 49                         Simon and Schuster
# 50                            Clarkson Potter
# 51                 Courier Dover Publications
# 52                                DK Children
# 53                          Bird Street Books
# 54                              Hill and Wang
# 55                         Workman Publishing
# 56                                 Zonderkidz
# 57                                 Penguin UK
# 58                               Little Simon
# 59                              HarperCollins

# %%
#Set index as book_id
df.index.name = 'Book_Id'

# %%
#Change column names: "genres" to "Themes", "pages" to "Total_Pages"
df.rename(columns={'Genre': 'Theme', 'pages': 'Total_Pages'}, inplace=True)

#Capitalize all columns

df.columns = [col.capitalize() for col in df.columns]
df.columns
# Out:
# Index(['Title', 'Author', 'Theme', 'Rating', 'Price', 'Year', 'Total_pages',
#        'Reviews', 'Amazon_year', 'Categories', 'Genres', 'Publisher'],
#       dtype='object')

# %%
#Remove "ratings" from the column "Reviews"
df['Reviews'] = df['Reviews'].str.replace('ratings', '', regex=False).str.strip()

# %%
df.head()
# Out:
#                                                      Title           Author  \
# Book_Id
# 0                     First 100 Words: A Padded Board Book     Roger Priddy
# 1        The Life-Changing Magic of Tidying Up: The Jap...      Marie Kondō
# 2                            Laugh-Out-Loud Jokes for Kids      Rob Elliott
# 3        Secret Garden: An Inky Treasure Hunt and Color...  Johanna Basford
# 4                                      StrengthsFinder 2.0           Gallup
#
#                                      Theme Rating  Price  Year Total_pages  \
# Book_Id
# 0                    Vocabulary & Spelling    4,7   3,88  2011          24
# 1        Cleaning, Caretaking & Relocating    4,5   9,42  2017         224
# 2                                 Humorous    4,6   4,64  2022         128
# 3                             Use of Color    4,7  10,18  2013          96
# 4                               Management    4,1  28,52  2007         175
#
#         Reviews  Amazon_year            Categories       Genres  \
# Book_Id
# 0        38.701         2015   Juvenile Nonfiction  Non Fiction
# 1        59.251         2015          House & Home  Non Fiction
# 2        12.125         2015   Juvenile Nonfiction  Non Fiction
# 3        15.936         2015                   Art  Non Fiction
# 4         8.423         2015  Business & Economics  Non Fiction
#
#                          Publisher
# Book_Id
# 0                  Priddy Books US
# 1                  Ten Speed Press
# 2                   Harper Collins
# 3        National Geographic Books
# 4                     Gallup Press

# %%
#Remove one ".." from the column "Price"
df['Price'] = df['Price'].str.replace('..', '.', regex=False).str.strip()

# %%
#Replace "." for "," in Rating and "," for "."" in "Reviews" and in Price
df['Price'] = df['Price'].str.replace('.', ',', regex=False).str.strip()
df['Reviews'] = df['Reviews'].str.replace(',', '.', regex=False).str.strip()

# %%
#Covert "Price" and "Rating" to float and "Reviews" to int
df['Rating'] = df['Rating'].astype(str).str.replace(',', '.', regex=False).astype(float)
df['Price'] = df['Price'].astype(str).str.replace(',', '.', regex=False).astype(float)

# %%
df['Reviews'] = df['Reviews'].str.replace(r'[^0-9]', '', regex=True).astype(int)

# %%
df.head(60)
# Out:
#                                                      Title  \
# Book_Id
# 0                     First 100 Words: A Padded Board Book
# 1        The Life-Changing Magic of Tidying Up: The Jap...
# 2                            Laugh-Out-Loud Jokes for Kids
# 3        Secret Garden: An Inky Treasure Hunt and Color...
# 4                                      StrengthsFinder 2.0
# 5                               Go Set a Watchman: A Novel
# 6        Enchanted Forest: An Inky Quest and Coloring b...
# 7                              All the Light We Cannot See
# 8                                    The Girl on the Train
# 9           Adult Coloring Book: Stress Relieving Patterns
# 10                    Diary of a Wimpy Kid #10: Old School
# 11                                   To Kill a Mockingbird
# 12       Adult Coloring Book: Stress Relieving Animal D...
# 13       Adult Coloring Books: A Coloring Book for Adul...
# 14                            Humans of New York : Stories
# 15                                             The Martian
# 16                               Oh, the Places You'll Go!
# 17       Knock-Knock Jokes for Kids: Knock-Knock Jokes ...
# 18                          Dear Zoo: A Lift-the-Flap Book
# 19                                The Day the Crayons Quit
# 21                     Sarah Young                      New Testament     4.9
# 22                  Carol S. Dweck                   Personal Finance     4.6
# 23                       E L James                       Contemporary     4.5
# 24                 Marjorie Sarnat                       Use of Color     4.8
# 25                   Dale Carnegie                            Unknown     4.7
# 26                    Gary Chapman                     Love & Romance     4.8
# 27                     Angie Grace                        Papercrafts     4.6
# 28                 Marjorie Sarnat                       Use of Color     4.7
# 29                    Thug Kitchen                              Vegan     4.6
# 30             F. Scott Fitzgerald                         Censorship     4.4
# 31                 Johanna Basford                                Art     4.7
# 32             Patrick M. Lencioni  Decision-Making & Problem Solving     4.6
# 33               The College Board                                SAT     4.4
# 34                        Jj Smith                        Weight Loss     4.7
# 35                     Brené Brown                         Creativity     4.7
# 36                 Bill Martin Jr.                   Beginner Readers     4.9
# 37                    Drew Daywalt                    Fantasy & Magic     4.8
# 38                  Randall Munroe               Science & Scientists     4.6
# 39                      John Green                         Friendship     4.2
# 40               Laura Hillenbrand                            Unknown     4.7
# 41           Laurence J. Kotlikoff       Budgeting & Money Management     4.2
# 42                    Rick Riordan                              Norse     4.6
# 43                      Adam Rubin       Dragons, Unicorns & Mythical     4.8
# 44                    Ray Bradbury                         Censorship     4.6
# 45                Valorie Schaefer                   Personal Hygiene     4.8
# 46               Leslie Patricelli                    New Experiences     4.7
# 47                  Randall Munroe               Patents & Inventions     4.6
# 48                     Erik Larson                            History     4.4
# 49                  Sandra Boynton                           Counting     4.8
# 50                    Ali Maffucci                Green Housecleaning     4.4
# 51              Alberta Hutchinson                     Coloring Books     4.5
# 52                              Dk                      Girls & Women     4.6
# 53                     Phil Mcgraw                        Weight Loss     4.0
# 54                     Elie Wiesel                          Holocaust     4.7
# 55         Heidi Eisenberg Murkoff             Pregnancy & Childbirth     4.5
# 56               Sally Lloyd-Jones                          Christian     4.9
# 57                    David Brooks                  Ethics & Morality     4.3
# 58                      Karen Katz               Anatomy & Physiology     4.8
# 59                    Paulo Coelho                         Historical     4.6
#
#          Price  Year Total_pages  Reviews  Amazon_year  \
# Book_Id
# 0         3.88  2011          24    38701         2015
# 1         9.42  2017         224    59251         2015
# 2         4.64  2022         128    12125         2015
# 3        10.18  2013          96    15936         2015
# 4        28.52  2007         175     8423         2015
# 5        12.95  2018         288    54069         2015
# 6        14.19  2015          84     8419         2015
# 7        12.93  2014         531   232435         2015
# 8        12.20  2014         336   494411         2015
# 9         9.95  2015          96     4363         2015
# 10        8.60  2002         224    33748         2015
# 11       21.68  1960         384   141123         2015
# 12        9.95  2021         136     4001         2015
# 13        8.99  2015          98     3203         2015
# 14       14.24  2015         432     5437         2015
# 15        8.99  1950         387   176360         2015
# 16        8.48  1990          56    52232         2015
# 17        4.64  2021         128     6123         2015
# 18        4.84  1725          18    31173         2015
# 19        9.50  2013          40    24358         2015
# 20       10.60  2019         404    91163         2015
# 21        9.09  2004         416    41717         2015
# 22       10.65  2021         320    22371         2015
# 23       12.12  2015         640   118522         2015
# 24        6.50  2015          64     5290         2015
# 25        9.99  1913         320    34768         2015
# 26        7.88  2016         224    93996         2015
# 27       11.95  2015         103     2295         2015
# 28        5.38  2015          64     5375         2015
# 29       15.89  2014         240    15131         2015
# 30        8.41  2004         180    17859         2015
# 31        9.19  2015          80     8737         2015
# 32        9.82  2002         256    13786         2015
# 33       39.22  2004         997     1580         2015
# 34        9.58  2014         192    38364         2015
# 35        8.71  2019         160    42847         2015
# 36        4.30  2012          36    40253         2015
# 37       11.36  2001          48     6213         2015
# 38       14.57  2014         352    18595         2015
# 39        8.24  2008         305    35855         2015
# 40        9.48  2014         528    76515         2015
# 41       12.12  2015         336     3619         2015
# 42       11.46  2015         512    24979         2015
# 43        9.95  2012          40    20113         2015
# 44        9.05  1953         249    55135         2015
# 45       12.99  2012         104    26974         2015
# 46        8.36  2016          28    14178         2015
# 47       14.89  2015          64     4752         2015
# 48       14.68  2015         430    32971         2015
# 49        3.86  1982          16    18895         2015
# 50       13.27  2015         224     3888         2015
# 51        3.99  2007          32     3053         2015
# 52        5.88  2013          16     5107         2015
# 53       11.71  2015         338     9007         2015
# 54        7.93  1734         120    21793         2015
# 55       19.76  2008         614     2107         2015
# 56       13.76  2012         352    13606         2015
# 57       14.78  2015         320     6379         2015
# 58        5.57  2000          14    14520         2015
# 59        7.85  2014         208   166954         2015
#
#                         Categories       Genres                   Publisher
# Book_Id
# 0              Juvenile Nonfiction  Non Fiction             Priddy Books US
# 1                     House & Home  Non Fiction             Ten Speed Press
# 2              Juvenile Nonfiction  Non Fiction              Harper Collins
# 3                              Art  Non Fiction   National Geographic Books
# 4             Business & Economics  Non Fiction                Gallup Press
# 5                          Fiction      Fiction                      Harper
# 6                              Art  Non Fiction    Laurence King Publishing
# 7                          Fiction      Fiction          Simon and Schuster
# 8                       Alcoholics  Non Fiction        Penguin Random House
# 9                              Art  Non Fiction             Blue Star Press
# 10                     Non Fiction  Non Fiction                Amulet Books
# 11                         Fiction      Fiction                       Arrow
# 12                             Art  Non Fiction             Blue Star Press
# 13                           Games  Non Fiction        Mother Dearest Books
# 14                     Photography  Non Fiction          St. Martin's Press
# 15                      Astronauts  Non Fiction   National Geographic Books
# 16                Juvenile Fiction      Fiction        Penguin Random House
# 17               Knock-knock jokes  Non Fiction                 Baker Books
# 18             Juvenile Nonfiction  Non Fiction          Simon and Schuster
# 19                Juvenile Fiction      Fiction        Penguin Random House
# 20             Sports & Recreation  Non Fiction        Penguin Random House
# 21                        Religion  Non Fiction               Thomas Nelson
# 22                     Non Fiction  Non Fiction        Penguin Random House
# 23                         Fiction      Fiction           Sourcebooks, Inc.
# 24                             Art  Non Fiction  Courier Dover Publications
# 25                       Self-Help  Non Fiction              Namaskar Books
# 26          Family & Relationships  Non Fiction            Moody Publishers
# 27                Crafts & Hobbies  Non Fiction         Grupo Planeta Spain
# 28                             Art  Non Fiction  Courier Dover Publications
# 29                         Cooking  Non Fiction                      Rodale
# 30                         Fiction      Fiction                    Scribner
# 31                             Art  Non Fiction   National Geographic Books
# 32            Business & Economics  Non Fiction           John Wiley & Sons
# 33                      Study Aids  Non Fiction               College Board
# 34                         Cooking  Non Fiction              Hay House, Inc
# 35                     Non Fiction  Non Fiction         Hazelden Publishing
# 36                Juvenile Fiction      Fiction            Beach Lane Books
# 37                         Fiction      Fiction        Penguin Random House
# 38                           Humor  Non Fiction                 Hachette UK
# 39             Young Adult Fiction      Fiction       Bloomsbury Publishing
# 40       Biography & Autobiography  Non Fiction        Penguin Random House
# 41            Business & Economics  Non Fiction          Simon and Schuster
# 42                Juvenile Fiction      Fiction                 Noura Books
# 43                Juvenile Fiction      Fiction                      Puffin
# 44                         Fiction      Fiction                   Minotauro
# 45             Juvenile Nonfiction  Non Fiction               American Girl
# 46                Juvenile Fiction      Fiction            Candlewick Press
# 47         Comics & Graphic Novels  Non Fiction                 Hachette UK
# 48                         History  Non Fiction                       Crown
# 49                Juvenile Fiction      Fiction          Simon and Schuster
# 50                         Cooking  Non Fiction             Clarkson Potter
# 51                             Art  Non Fiction  Courier Dover Publications
# 52                     Non Fiction  Non Fiction                 DK Children
# 53                Health & Fitness  Non Fiction           Bird Street Books
# 54       Biography & Autobiography  Non Fiction               Hill and Wang
# 55                Health & Fitness  Non Fiction          Workman Publishing
# 56             Juvenile Nonfiction  Non Fiction                  Zonderkidz
# 57                       Self-Help  Non Fiction        Penguin Random House
# 58                           Games  Non Fiction                Little Simon
# 59                         Fiction      Fiction              Harper Collins

# %%
#Let´s add a space in between words for publisher

df['Publisher'] = df['Publisher'].apply(lambda x: re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', x))

# %%
#Ok, so Harper in oublisher is Harper Collins, let´s replace that
df['Publisher'] = df['Publisher'].str.replace(r'Harper\s?Collins', 'Harper Collins', regex=True)
#Group all Penguin, Random House together
df['Publisher'] = df['Publisher'].str.replace(
    r'(?i)\b(penguin.*|random house.*)\b', 'Penguin Random House', regex=True
)

# %%
#Replace some publishers that I see are wrong
df.loc[df['Title'].str.contains('atomic habits', case=False, na=False), 'Publisher'] = 'Penguin Random House'
df.loc[df['Title'].str.contains('the house of my mother', case=False, na=False), 'Publisher'] = 'Simon and Schuster'
df.loc[df['Title'].str.contains("Don't Believe Everything You Think", case=False, na=False), 'Publisher'] = 'Authors Equity'

# %%
#Correct Authors names
df['Author'] = df['Author'].str.title()

# %%
df.tail(60)
# Out:
#                                                      Title  \
# Book_Id
# 596      The Let Them Theory: A Life-Changing Tool That...
# 597      Sunrise on the Reaping (A Hunger Games Novel) ...
# 598      Forgotten Home Apothecary : 250 Powerful Remed...
# 599      Onyx Storm (Deluxe Limited Edition) (The Empyr...
# 600      INNER EXCELLENCE: Train Your Mind for Extraord...
# 601      Atomic Habits: An Easy & Proven Way to Build G...
# 602                                          The Housemaid
# 603      Girl Moments: Coloring Book for Adults and Tee...
# 604      Cozy Friends: Coloring Book for Adults and Tee...
# 605        The Frozen River: A GMA Book Club Pick: A Novel
# 606      Little Corner: Coloring Book for Adults and Te...
# 607        Onyx Storm (Standard Edition) (The Empyrean, 3)
# 608      The Anxious Generation: How the Great Rewiring...
# 619      17.06  2017         320    64489         2025
# 620       9.78  1984         328   117019         2025
# 621       8.27  2024         224     4570         2025
# 622      17.00  2024         496    72959         2025
# 623       5.75  1969          26    76709         2025
# 624      22.39  2020         256    61641         2025
# 625      18.37  2024         384    76073         2025
# 626      15.06  2018         220    82979         2025
# 627       9.00  2020          20    11624         2025
# 628      20.81  2024         240     1652         2025
# 629       8.95  1985         311   165767         2025
# 630      14.98  2022         127    17068         2025
# 631       7.05  1997         160   117066         2025
# 632       4.30  2012          36    40253         2025
# 633      17.95  2020        1400    12890         2025
# 634      15.80  2020         208    28326         2025
# 635      16.92  2024         400     3645         2025
# 636      10.02  2016          32    11346         2025
# 637      23.09  2025         400     2978         2025
# 638      17.10  2025         320     9127         2025
# 639       5.98  1983          48    20261         2025
# 640       5.68  2011          14    11955         2025
# 641      10.64  1980         784    15637         2025
# 642      36.15  2022        2896    44679         2025
# 643       7.57  2018          16    16497         2025
# 644      17.34  2006         304     1173         2025
# 645      12.54  2024         192    17068         2025
# 646       7.98  2025          32      694         2025
# 647       8.72  2018         576   178153         2025
# 648      43.47  2023         320     2193         2025
# 649      20.36  2025         400     1165         2025
# 650       3.99  2024          84    67773         2025
# 651      10.05  2024         448   279098         2025
# 652       7.99  2024          88     4036         2025
# 653       8.48  1990          56    52232         2025
# 654       9.99  1990         368   191449         2025
# 655      10.73  2016         656    29479         2025
#
#                         Categories       Genres  \
# Book_Id
# 596                      Self-Help  Non Fiction
# 597               Juvenile Fiction      Fiction
# 598                    Non Fiction  Non Fiction
# 599                        Fiction      Fiction
# 600                      Self-Help  Non Fiction
# 601                    Non Fiction  Non Fiction
# 602                        Fiction      Fiction
# 603             Games & Activities  Non Fiction
# 604             Games & Activities  Non Fiction
# 605                        Fiction      Fiction
# 606             Games & Activities  Non Fiction
# 607                        Fiction      Fiction
# 608                     Psychology  Non Fiction
# 609                        Fiction      Fiction
# 610                            Art  Non Fiction
# 611                        Fiction      Fiction
# 612                        Fiction      Fiction
# 613                        Fiction      Fiction
# 614            Juvenile Nonfiction  Non Fiction
# 615                    Non Fiction  Non Fiction
# 616                     Psychology  Non Fiction
# 617                        Fiction      Fiction
# 618                        Fiction      Fiction
# 619                        Fiction      Fiction
# 620                        Fiction      Fiction
# 621               Juvenile Fiction      Fiction
# 622                        Fiction      Fiction
# 623               Juvenile Fiction      Fiction
# 624           Business & Economics  Non Fiction
# 625                        Fiction      Fiction
# 626         Young Adult Nonfiction  Non Fiction
# 627               Juvenile Fiction      Fiction
# 628           Emergency management  Non Fiction
# 629                        Fiction      Fiction
# 630                      Self-Help  Non Fiction
# 631                      Self-Help  Non Fiction
# 632               Juvenile Fiction      Fiction
# 633                    Non Fiction  Non Fiction
# 634                       Religion  Non Fiction
# 635               Health & Fitness  Non Fiction
# 636               Juvenile Fiction      Fiction
# 637                 Social Science  Non Fiction
# 638      Biography & Autobiography  Non Fiction
# 639               Juvenile Fiction      Fiction
# 640               Juvenile Fiction      Fiction
# 641                        History  Non Fiction
# 642                        Fiction      Fiction
# 643               Juvenile Fiction      Fiction
# 644              Political Science  Non Fiction
# 645                      Self-Help  Non Fiction
# 646               Juvenile Fiction      Fiction
# 647                        Fiction      Fiction
# 648                    Non Fiction  Non Fiction
# 649                      Self-Help  Non Fiction
# 650                       Weddings  Non Fiction
# 651                        Fiction      Fiction
# 652                            Art  Non Fiction
# 653               Juvenile Fiction      Fiction
# 654                        Fiction      Fiction
# 655               Health & Fitness  Non Fiction
#
#                                            Publisher
# Book_Id
# 596                                   Hay House, Inc
# 597                             Scholastic Australia
# 598                          Independently Published
# 599                                Alcaraz Ediciones
# 600                                      Hachette UK
# 601                             Penguin Random House
# 602                                             Suma
# 603                                 Turtleback Books
# 604      Createspace Independent Publishing Platform
# 605                                    LA CASE Books
# 606                          Independently Published
# 607                                Alcaraz Ediciones
# 608                             Penguin Random House
# 609                               St. Martin's Press
# 610                                 Gedisa Editorial
# 611                               St. Martin's Press
# 612                      Thorndike Press Large Print
# 613                                       Hugo Roman
# 614                                  Rockridge Press
# 615                                Sourcebooks, Inc.
# 616                             Penguin Random House
# 617                                        Minotauro
# 618                                         Anagrama
# 619                                        Doubleday
# 620                                          Berkley
# 621                                  Scholastic Inc.
# 622                             Penguin Random House
# 623                             Penguin Random House
# 624                           Harriman House Limited
# 625                           Henry Holt and Company
# 626                               Wonder House Books
# 627                                    Clarion Books
# 628                                         Anagrama
# 629                                    Jonathan Cape
# 630                                   Authors Equity
# 631      Createspace Independent Publishing Platform
# 632                                 Beach Lane Books
# 633                 Christian Art Gifts Incorporated
# 634                                Sourcebooks, Inc.
# 635                             Penguin Random House
# 636                                Sourcebooks, Inc.
# 637                                   Flatiron Books
# 638                               Simon and Schuster
# 639                             Penguin Random House
# 640                             Penguin Random House
# 641                                Harper Paperbacks
# 642                            Bloomsbury Publishing
# 643                                   Harper Collins
# 644                               Simon and Schuster
# 645                                   Authors Equity
# 646                             Penguin Random House
# 647                               St. Martin's Press
# 648                                     Claude Davis
# 649                             Penguin Random House
# 650                                 Freida Mc Fadden
# 651                            Bloomsbury Publishing
# 652                                     Amelia Green
# 653                             Penguin Random House
# 654                               Poisoned Pen Press
# 655                               Simon and Schuster

# %% [markdown]
# Looks good! Letés check if I have any NaNs

# %%
df.isna().mean()*100
# Out:
# Title          0.0
# Author         0.0
# Theme          0.0
# Rating         0.0
# Price          0.0
# Year           0.0
# Total_pages    0.0
# Reviews        0.0
# Amazon_year    0.0
# Categories     0.0
# Genres         0.0
# Publisher      0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        656 non-null    object
#  1   Author       656 non-null    object
#  2   Theme        656 non-null    object
#  3   Rating       656 non-null    float64
#  4   Price        656 non-null    float64
#  5   Year         656 non-null    int64
#  6   Total_pages  656 non-null    object
#  7   Reviews      656 non-null    int64
#  8   Amazon_year  656 non-null    int64
#  9   Categories   656 non-null    object
#  10  Genres       656 non-null    object
#  11  Publisher    656 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 61.6+ KB

# %% [markdown]
# Future Work:
#
# We can preprocess the datasets that are extracted from Amazon. Preprocessing can include the following.
#
# Replacing the missing values if any with the appropriate values.
# Removing the duplicated rows.
# Taking a note of any unusual values.
# Adjusting the outliers as they can hamper the further analysis of the data.
#
# We can analyze the datasets further to check the following.
# Which genre is the most popular with highest user ratings?
# List of Authors which have top selling books in the multiple genres?
# List of Authors having multiple top selling books in the same genre?
# Top 10 books with the maximum selling price across all the genres.
# What is the trend of star rating and number of user ratings?
# Books which have the highest star ratings and highest number of user ratings.

# %% [markdown]
# | Columna/Variable | Descripción |
# | ---------------- | ----------- |
# | Title     | Title of the book|
# | Author    | Author of the book |
# | Theme   | Recurring themes of the book |
# | Rating    | Average rating of the book, by amazon customers |
# | Price    | Book price on amazon (in $) |
# | Year   | Year it was published |
# | Total_pages     | Number of pages in the book|
# | Reviews     | Number of reviews for the book  |
# | Amazon_year    | Year it was a bestseller on Amazon|
# | Categories | Fiction on Non Fiction |
# | Genres    | Genre of the book |
# | Publisher   | Publishing house for the book |

# %%
# Check for duplicate rows (based on all columns)
duplicate_rows = df[df.duplicated()]

# Or check for duplicates based on specific columns (e.g., title + author)
duplicate_titles = df[df.duplicated(subset=["Title", "Author"])]

# See how many there are
print("Total full duplicates:", len(duplicate_rows))
print("Total title-author duplicates:", len(duplicate_titles))

# Show examples
print(duplicate_titles[["Title", "Author"]].head())
# Out:
# Total full duplicates: 0
# Total title-author duplicates: 253
#                                                      Title        Author
# Book_Id
# 61                                     StrengthsFinder 2.0        Gallup
# 62                    First 100 Words: A Padded Board Book  Roger Priddy
# 63       The Life-Changing Magic of Tidying Up: The Jap...   Marie Kondō
# 64                               Oh, the Places You'll Go!     Dr. Seuss
# 68       The 5 Love Languages: The Secret to Love that ...  Gary Chapman

# %%
# Primero dividir las variables por tipo, usando la función que programamos en los ejercicios
def card_tipo(df,umbral_categoria = 13, umbral_continua = 10):
    # Primera parte: Preparo el dataset con cardinalidades, % variación cardinalidad, y tipos
    df_temp = pd.DataFrame([df.nunique(), df.nunique()/len(df) * 100, df.dtypes]) # Cardinaliad y porcentaje de variación de cardinalidad
    df_temp = df_temp.T # Como nos da los valores de las columnas en columnas, y quiero que estas sean filas, la traspongo
    df_temp = df_temp.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"}) # Cambio el nombre de la transposición anterior para que tengan más sentido, y uso asignación en vez de inplace = True (esto es arbitrario para el tamaño de este dataset)

    # Corrección para cuando solo tengo un valor
    df_temp.loc[df_temp.Card == 1, "%_Card"] = 0.00

    # Creo la columna de sugerenica de tipo de variable, empiezo considerando todas categóricas pero podría haber empezado por cualquiera, siempre que adapte los filtros siguientes de forma correspondiente
    df_temp["tipo_sugerido"] = "Categorica"
    df_temp.loc[df_temp["Card"] == 2, "tipo_sugerido"] = "Binaria"
    df_temp.loc[df_temp["Card"] >= umbral_categoria, "tipo_sugerido"] = "Numerica discreta"
    df_temp.loc[df_temp["%_Card"] >= umbral_continua, "tipo_sugerido"] = "Numerica continua"
    # Ojo los filtros aplicados cumplen con el enunciado pero no siguen su orden y planteamiento

# %%
card_tipo(df)
